# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# # Loading Data

# %%
train_stdf0 = pd.read_csv('./drive/Shareddrives/DATA 298A/DATA/train_stdf.csv')
pd.set_option('display.max_columns',None)

# %%
train_stdf0.drop(columns=['Clear', 'Freezing Drizzle/Freezing Rain, Overcast',
              'Ice, Overcast', 'Overcast', 'Partially cloudy', 'Rain', 'Rain, Overcast',
              'Rain, Partially cloudy', 'Snow, Overcast', 'Snow, Partially cloudy',
              'Snow, Rain, Overcast','Snow, Rain, Partially cloudy'], inplace=True)
train_stdf0.head()
# Out:
#    Year  Month  Day  Hour       GHI       TmpF  output   dew  humidity  \
# 0  2016     10    1     0  0.000000  56.997313     0.0  53.3     87.78
# 1  2016     10    1     1  0.000000  56.929524     0.0  53.3     91.47
# 2  2016     10    1     2  0.001702  57.055018     0.0  54.0     93.96
# 3  2016     10    1     3  0.065986  57.198007     1.0  54.0     92.12
# 4  2016     10    1     4  0.163879  57.340995     0.0  54.1     93.36
#
#    precip  snow  sealevelpressure  cloudcover  visibility  solarradiation  \
# 0   0.025   0.0            1016.3        72.8         6.6             0.0
# 1   0.005   0.0            1016.4        94.8         7.0             0.0
# 2   0.000   0.0            1016.5       100.0         4.0             0.0
# 3   0.021   0.0            1016.5        97.7         4.2             0.0
# 4   0.000   0.0            1016.3        97.7         4.4             0.0
#
#          date
# 0  2016-10-01
# 1  2016-10-01
# 2  2016-10-01
# 3  2016-10-01
# 4  2016-10-01

# %%
print('train initial shape:', train_stdf0.shape)
# Out:
# train initial shape: (37273, 16)

# %%
test_stdf0 = pd.read_csv('./drive/Shareddrives/DATA 298A/DATA/test_stdf.csv')

# %%
test_stdf0.drop(columns=['Clear', 'Freezing Drizzle/Freezing Rain, Overcast',
              'Ice, Overcast', 'Overcast', 'Partially cloudy', 'Rain', 'Rain, Overcast',
              'Rain, Partially cloudy', 'Snow, Overcast', 'Snow, Partially cloudy',
              'Snow, Rain, Overcast','Snow, Rain, Partially cloudy'], inplace=True)
test_stdf0_copy = test_stdf0.copy()
test_stdf0.head()
# Out:
#    Year  Month  Day  Hour        GHI       TmpF  output   dew  humidity  \
# 0  2021      9    1     0  11.765049  50.945201     0.0  69.2     93.29
# 1  2021      9    1     1  12.894517  50.952983     0.0  69.2     94.42
# 2  2021      9    1     2  14.023986  50.960765     0.0  68.8     93.23
# 3  2021      9    1     3  15.153455  50.968547     0.0  68.2     91.47
# 4  2021      9    1     4  16.282923  50.976329     0.0  67.9     90.32
#
#    precip  snow  sealevelpressure  cloudcover  visibility  solarradiation  \
# 0   0.051   0.0            1004.1       100.0         6.7             0.0
# 1   0.017   0.0            1004.0       100.0         8.4             0.0
# 2   0.008   0.0            1003.6       100.0         8.5             0.0
# 3   0.050   0.0            1004.0       100.0         8.4             0.0
# 4   0.009   0.0            1004.1       100.0         8.6             0.0
#
#          date
# 0  2021-09-01
# 1  2021-09-01
# 2  2021-09-01
# 3  2021-09-01
# 4  2021-09-01

# %%
test_rf = test_stdf0.drop(columns='output')

# %%
test_rf.head()
# Out:
#    Year  Month  Day  Hour        GHI       TmpF   dew  humidity  precip  snow  \
# 0  2021      9    1     0  11.765049  50.945201  69.2     93.29   0.051   0.0
# 1  2021      9    1     1  12.894517  50.952983  69.2     94.42   0.017   0.0
# 2  2021      9    1     2  14.023986  50.960765  68.8     93.23   0.008   0.0
# 3  2021      9    1     3  15.153455  50.968547  68.2     91.47   0.050   0.0
# 4  2021      9    1     4  16.282923  50.976329  67.9     90.32   0.009   0.0
#
#    sealevelpressure  cloudcover  visibility  solarradiation        date
# 0            1004.1       100.0         6.7             0.0  2021-09-01
# 1            1004.0       100.0         8.4             0.0  2021-09-01
# 2            1003.6       100.0         8.5             0.0  2021-09-01
# 3            1004.0       100.0         8.4             0.0  2021-09-01
# 4            1004.1       100.0         8.6             0.0  2021-09-01

# %%
test_rf.to_csv('/content/drive/Shareddrives/DATA 298A/output/TestFile_rf.csv',index=False)

# %%
test_twostep = test_stdf0.drop(columns=['output'])

# %%
test_twostep.to_csv('/content/drive/Shareddrives/DATA 298A/output/TestFile_2step.csv',index=False)

# %%
# remove 'date' column that has the full date
train_stdf0.drop(columns='date', inplace=True)
test_stdf0.drop(columns='date', inplace=True)

print('Train Dataset:',train_stdf0.shape)
print('Test Dataset:',test_stdf0.shape)
# Out:
# Train Dataset: (37273, 15)
# Test Dataset: (10224, 15)

# %% [markdown]
# # Dividing the Sets

# %%
xst_train0 = train_stdf0.drop(columns=['output','GHI'])
y_train0 = train_stdf0['GHI']
xst_test0 = test_stdf0.drop(columns=['output','GHI'])
y_test0 = test_stdf0['GHI']

print('Train Dataset:',xst_train0.shape, y_train0.shape)
print('Test Dataset:',xst_test0.shape, y_test0.shape)
# Out:
# Train Dataset: (37273, 13) (37273,)
# Test Dataset: (10224, 13) (10224,)

# %%
test_twostep.head()
# Out:
#    Year  Month  Day  Hour        GHI       TmpF   dew  humidity  precip  snow  \
# 0  2021      9    1     0  11.765049  50.945201  69.2     93.29   0.051   0.0
# 1  2021      9    1     1  12.894517  50.952983  69.2     94.42   0.017   0.0
# 2  2021      9    1     2  14.023986  50.960765  68.8     93.23   0.008   0.0
# 3  2021      9    1     3  15.153455  50.968547  68.2     91.47   0.050   0.0
# 4  2021      9    1     4  16.282923  50.976329  67.9     90.32   0.009   0.0
#
#    sealevelpressure  cloudcover  visibility  solarradiation        date
# 0            1004.1       100.0         6.7             0.0  2021-09-01
# 1            1004.0       100.0         8.4             0.0  2021-09-01
# 2            1003.6       100.0         8.5             0.0  2021-09-01
# 3            1004.0       100.0         8.4             0.0  2021-09-01
# 4            1004.1       100.0         8.6             0.0  2021-09-01

# %%
xst_test0
# Out:
#        Year  Month  Day  Hour       TmpF   dew  humidity  precip  snow  \
# 0      2021      9    1     0  50.945201  69.2     93.29   0.051   0.0
# 1      2021      9    1     1  50.952983  69.2     94.42   0.017   0.0
# 2      2021      9    1     2  50.960765  68.8     93.23   0.008   0.0
# 3      2021      9    1     3  50.968547  68.2     91.47   0.050   0.0
# 4      2021      9    1     4  50.976329  67.9     90.32   0.009   0.0
# ...     ...    ...  ...   ...        ...   ...       ...     ...   ...
# 10219  2022     10   31    19  60.611901  56.9     80.58   0.006   0.0
# 10220  2022     10   31    20  59.977662  57.0     87.25   0.009   0.0
# 10221  2022     10   31    21  59.358295  57.8     94.30   0.187   0.0
# 10222  2022     10   31    22  59.023864  57.2     92.82   0.009   0.0
# 10223  2022     10   31    23  58.876139  56.9     94.28   0.007   0.0
#
#        sealevelpressure  cloudcover  visibility  solarradiation
# 0                1004.1       100.0         6.7             0.0
# 1                1004.0       100.0         8.4             0.0
# 2                1003.6       100.0         8.5             0.0
# 3                1004.0       100.0         8.4             0.0
# 4                1004.1       100.0         8.6             0.0
# ...                 ...         ...         ...             ...
# 10219            1012.8        96.5         9.9            16.0
# 10220            1014.0       100.0         5.5            38.0
# 10221            1014.6       100.0         3.7            38.0
# 10222            1014.8       100.0         9.9            38.0
# 10223            1015.4       100.0         9.2            38.0
#
# [10224 rows x 13 columns]

# %% [markdown]
# # Build Model

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score

# %%
# From 'Optimized Random Forest for Solar Radiation Prediction Using Sunshine Hours', from Villegas-Mier
# Results obtained after determining the best features for the RF algorithm.
# n_estimators: 500, max_features: 4, min_samples_leaf: 2 ,maximum_depth

# Instantiate model with 500 decision trees
rf_500 = RandomForestRegressor(n_estimators=500, max_features=4, random_state=42)

# %%
def plot_predictions(test_df, y_test, valid_preds):
    
    rmse = mean_squared_error(y_test, valid_preds, squared=False)
    
    nrows, ncols = 1, 1
    fig, ax = plt.subplots(nrows, ncols, figsize=(20,4))

    ax1 = plt.subplot(nrows, ncols, 1)
    ax1.plot(test_df['date'].values, y_test, c='tab:purple')
    ax1.scatter(test_df['date'].values, valid_preds, s=5, c='#7FB285')
    ax1.set_ylabel('Solar Power Generation')
    ax1.set_xlabel('Date')
    ax1.xaxis.set_major_locator(plt.MaxNLocator(10))
    ax1.set_title('Prediction RMSE: {:.4f}'.format(rmse), fontsize=10)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Standardized Data

# %% [markdown]
# #### Train

# %%
# Train the model on training data
rf_500.fit(xst_train0, y_train0)
# Out:
# RandomForestRegressor(max_features=4, n_estimators=500, random_state=42)

# %%
import pickle
from pathlib import Path

# %%
Pkl_Filename = "Pickle_TwoStep_rf_Model.pkl"  

with open(Pkl_Filename, 'wb') as file:  
    pickle.dump(rf_500, file)

# %% [markdown]
# #### Predict

# %%
yst0_pred_500 = rf_500.predict(xst_test0)

# %%
test_data = xst_test0.iloc[1235:1236]
from time import process_time
t1_start = process_time() 
test_prediction = rf_500.predict(test_data)
t1_stop = process_time()
test_prediction

print("Elapsed time:", t1_stop, t1_start) 
   
print("Elapsed time during the whole program in seconds:",
                                         t1_stop-t1_start)
# Out:
# Elapsed time: 69.924106365 69.874484318
# Elapsed time during the whole program in seconds: 0.049622046999999725

# %%
test_stdf0.iloc[1235:1236]
# Out:
#       Year  Month  Day  Hour         GHI       TmpF  output   dew  humidity  \
# 1235  2021     10   22    11  186.397208  43.161421  2064.0  48.4     79.87
#
#       precip  snow  sealevelpressure  cloudcover  visibility  solarradiation
# 1235     0.0   0.0            1018.9       100.0         9.6           136.0

# %%
test_data
# Out:
#       Year  Month  Day  Hour       TmpF   dew  humidity  precip  snow  \
# 1235  2021     10   22    11  43.161421  48.4     79.87     0.0   0.0
#
#       sealevelpressure  cloudcover  visibility  solarradiation
# 1235            1018.9       100.0         9.6           136.0

# %% [markdown]
# #### Evaluate

# %%
mae_500_st0 = mean_absolute_error(y_test0, yst0_pred_500)
print('Mean Absolute Error (MAE):', round(mae_500_st0, 2))
# The model is the most accurate when its MAE is closer to 0.
# Out:
# Mean Absolute Error (MAE): 58.6

# %%
# accuracy
mape_500_st0 = mean_absolute_percentage_error(y_test0, yst0_pred_500)
print('Mean Absolute Percentage Error (MAPE):', round(mape_500_st0, 2))
# A MAPE score of less than 5% indicated that the model has great predictive power.
# In Scikit Learn Library
# Note here that the output is not a percentage in the range [0, 100] and a value
# of 100 does not mean 100% but 1e2. Furthermore, the output can be arbitrarily
# high when y_true is small (which is specific to the metric) or when
# abs(y_true - y_pred) is large (which is common for most regression metrics)
# Out:
# Mean Absolute Percentage Error (MAPE): 1.0733566452119206e+16

# %%
rmse_500_st0 = mean_squared_error(y_test0, yst0_pred_500, squared=False)
print('Root Mean Squared Error (RMSE):', round(rmse_500_st0, 2))
# Out:
# Root Mean Squared Error (RMSE): 120.73

# %%
r2_500_st0 = r2_score(y_test0, yst0_pred_500)
print('R^2:', round(r2_500_st0, 2))
# The closer R^2 is to 1, the better the model fits to the data and the more accurate it is.
# Out:
# R^2: 0.79

# %% [markdown]
# ## SVR

# %%
train_stdf0
# Out:
#        Year  Month  Day  Hour       GHI       TmpF  output   dew  humidity  \
# 0      2016     10    1     0  0.000000  56.997313     0.0  53.3     87.78
# 1      2016     10    1     1  0.000000  56.929524     0.0  53.3     91.47
# 2      2016     10    1     2  0.001702  57.055018     0.0  54.0     93.96
# 3      2016     10    1     3  0.065986  57.198007     1.0  54.0     92.12
# 4      2016     10    1     4  0.163879  57.340995     0.0  54.1     93.36
# ...     ...    ...  ...   ...       ...        ...     ...   ...       ...
# 37268  2020     12   31    20  0.000000  35.712371     0.0  28.8     80.99
# 37269  2020     12   31    21  0.000000  35.865356     0.0  29.1     81.07
# 37270  2020     12   31    22  0.000000  36.018342     0.0  29.1     81.74
# 37271  2020     12   31    23  0.000000  36.171328     0.0  28.8     80.13
# 37272  2021      1    1     0  0.116229  37.309328     0.0  29.5     79.96
#
#        precip  snow  sealevelpressure  cloudcover  visibility  solarradiation
# 0       0.025   0.0            1016.3        72.8         6.6             0.0
# 1       0.005   0.0            1016.4        94.8         7.0             0.0
# 2       0.000   0.0            1016.5       100.0         4.0             0.0
# 3       0.021   0.0            1016.5        97.7         4.2             0.0
# 4       0.000   0.0            1016.3        97.7         4.4             0.0
# ...       ...   ...               ...         ...         ...             ...
# 37268   0.000   0.0            1025.6       100.0         8.3             3.0
# 37269   0.000   0.0            1024.9       100.0         7.4             0.0
# 37270   0.000   0.0            1025.4       100.0         8.8             0.0
# 37271   0.000   0.0            1025.0       100.0         8.7             0.0
# 37272   0.000   0.0            1024.8       100.0         9.1             0.0
#
# [37273 rows x 15 columns]

# %%
train_stdf0['previous_output']=train_stdf0['output'].shift(1)
test_stdf0['previous_output']=test_stdf0['output'].shift(1)

# %%
train_stdf0.fillna(0, inplace=True)
test_stdf0.fillna(0, inplace=True)

# %%
x_train_svr = train_stdf0[['Month','Day','Hour','GHI','previous_output']]
y_train_svr = train_stdf0['output']
x_test_svr = test_stdf0[['Month','Day','Hour','GHI','previous_output']]
y_test_svr = test_stdf0['output']

print('Train Dataset:',x_train_svr.shape, y_train_svr.shape)
print('Test Dataset:',x_test_svr.shape, y_test_svr.shape)
# Out:
# Train Dataset: (37273, 5) (37273,)
# Test Dataset: (10224, 5) (10224,)

# %% [markdown]
# ### converting data to numpy

# %%
x_train_svr=x_train_svr.to_numpy()
y_train_svr=y_train_svr.to_numpy()

# %%
#xst_train0= xst_train0.reshape(-1,1)
y_train_svr = y_train_svr.reshape(-1,1)

# %%
x_train_svr
# Out:
# array([[1.00000000e+01, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [1.00000000e+01, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [1.00000000e+01, 1.00000000e+00, 2.00000000e+00, 1.70184583e-03,
#         0.00000000e+00],
#        ...,
#        [1.20000000e+01, 3.10000000e+01, 2.20000000e+01, 0.00000000e+00,
#         0.00000000e+00],
#        [1.20000000e+01, 3.10000000e+01, 2.30000000e+01, 0.00000000e+00,
#         0.00000000e+00],
#        [1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.16228677e-01,
#         0.00000000e+00]])

# %%
x_test_svr=x_test_svr.to_numpy()
y_test_svr=y_test_svr.to_numpy() 
#xst_test0= xst_test0.reshape(-1,1)
y_test_svr = y_test_svr.reshape(-1,1)

# %% [markdown]
# ### Importing SVR

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(x_train_svr)
y = sc_y.fit_transform(y_train_svr)

# %%
x_test = sc_X.fit_transform(x_test_svr)
y_test = sc_y.fit_transform(y_test_svr)

# %%
from sklearn.svm import SVR

# %%
regressor = SVR(kernel='rbf')
regressor.fit(X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
Pkl_Filename = "Pickle_TwoStep_SVR_Model.pkl"  

with open(Pkl_Filename, 'wb') as file:  
    pickle.dump(regressor, file)

# %%
y_pred = regressor.predict(x_test)

# %%
r2= r2_score(y_test, y_pred)
print('R^2:', round(r2, 2))
# The closer R^2 is to 1, the better the model fits to the data and the more accurate it is.
# Out:
# R^2: 0.94

# %%
x_test_rf_output = test_stdf0[['Month','Day','Hour','GHI','previous_output']]
y_test_rf_output = test_stdf0['output']

# %%
x_test_rf_output['GHI']= yst0_pred_500
# Out:
# <ipython-input-71-61864f89e79c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test_rf_output['GHI']= yst0_pred_500

# %%
x_test_rf_output
# Out:
#        Month  Day  Hour       GHI  previous_output
# 0          9    1     0  4.009299              0.0
# 1          9    1     1  2.144609              0.0
# 2          9    1     2  2.080891              0.0
# 3          9    1     3  2.035817              0.0
# 4          9    1     4  1.949373              0.0
# ...      ...  ...   ...       ...              ...
# 10219     10   31    19  5.634462              0.0
# 10220     10   31    20  5.530043              0.0
# 10221     10   31    21  8.540075              0.0
# 10222     10   31    22  7.989831              0.0
# 10223     10   31    23  6.996645              0.0
#
# [10224 rows x 5 columns]

# %%
x_test_rf_output=x_test_rf_output.to_numpy()
y_test_rf_output=y_test_rf_output.to_numpy() 
#xst_test0= xst_test0.reshape(-1,1)
y_test_rf_output = y_test_rf_output.reshape(-1,1)

# %%
x_test = sc_X.fit_transform(x_test_rf_output)
y_test = sc_y.fit_transform(y_test_rf_output)

# %%
y_pred = regressor.predict(x_test)

# %%
r2= r2_score(y_test, y_pred)
print('R^2:', round(r2, 2))
# The closer R^2 is to 1, the better the model fits to the data and the more accurate it is.
# Out:
# R^2: 0.92

# %%
y_pred=y_pred.reshape(-1,1)

# %%
y_pred = sc_y.inverse_transform(y_pred)

# %%
mae_500_st = mean_absolute_error(y_test_rf_output, y_pred)
print('Mean Absolute Error (MAE):', round(mae_500_st, 2))
# The model is the most accurate when its MAE is closer to 0.
# Out:
# Mean Absolute Error (MAE): 468.36

# %%
mape_500_st0 = mean_absolute_percentage_error(y_test_rf_output, y_pred)
print('Mean Absolute Percentage Error (MAPE):', round(mape_500_st0, 2))
# Out:
# Mean Absolute Percentage Error (MAPE): 2.739428205831483e+17

# %%
rmse_500_st0 = mean_squared_error(y_test_rf_output, y_pred, squared=False)
print('Root Mean Squared Error (RMSE):', round(rmse_500_st0, 2))
# Out:
# Root Mean Squared Error (RMSE): 824.24

# %%
def GetWeeklyOutput(test_data,predictionData):
  """
  The function takes hourly test data and hourly predictions
  and retruns weekly test data and weekly predictions
  """
  df = test_data[['date','output']]
  df['prediction'] = predictionData
  # Convert the date column to a datetime format
  df['date'] = pd.to_datetime(df['date'])

  # Set the date column as the index column
  df.set_index('date', inplace=True)

  # Resample to weekly intervals
  weekly_df = df.resample('W').mean()

  return weekly_df

# %%
def GetMonthlyOutput(test_data,predictionData):
  """
  The function takes hourly test data and hourly predictions
  and retruns monthly test data and monthly predictions
  """
  df = test_data[['date','output']]
  df['prediction'] = predictionData
  # Convert the date column to a datetime format
  df['date'] = pd.to_datetime(df['date'])

  # Set the date column as the index column
  df.set_index('date', inplace=True)

  # Resample to weekly intervals
  monthly_df = df.resample('M').mean()
  return monthly_df

# %%
def GetDailyOutput(test_data,predictionData):
  """
  The function takes hourly test data and hourly predictions
  and retruns daily test data and daily predictions
  """
  y_test_daily =test_data.groupby(['Year','Month','Day']).agg({'output': 'sum'})
  test_data_v1 = test_data.copy()
  test_data_v1['prediction'] = predictionData

  y_pred_daily =  test_data_v1.groupby(['Year','Month','Day']).agg({'prediction': 'sum'})

  return y_test_daily,y_pred_daily

# %%
test_stdf0_copy
# Out:
#        Year  Month  Day  Hour        GHI       TmpF  output   dew  humidity  \
# 0      2021      9    1     0  11.765049  50.945201     0.0  69.2     93.29
# 1      2021      9    1     1  12.894517  50.952983     0.0  69.2     94.42
# 2      2021      9    1     2  14.023986  50.960765     0.0  68.8     93.23
# 3      2021      9    1     3  15.153455  50.968547     0.0  68.2     91.47
# 4      2021      9    1     4  16.282923  50.976329     0.0  67.9     90.32
# ...     ...    ...  ...   ...        ...        ...     ...   ...       ...
# 10219  2022     10   31    19   0.000000  60.611901     0.0  56.9     80.58
# 10220  2022     10   31    20   0.000000  59.977662     0.0  57.0     87.25
# 10221  2022     10   31    21   0.000000  59.358295     0.0  57.8     94.30
# 10222  2022     10   31    22   0.000000  59.023864     0.0  57.2     92.82
# 10223  2022     10   31    23   0.000000  58.876139     0.0  56.9     94.28
#
#        precip  snow  sealevelpressure  cloudcover  visibility  solarradiation  \
# 0       0.051   0.0            1004.1       100.0         6.7             0.0
# 1       0.017   0.0            1004.0       100.0         8.4             0.0
# 2       0.008   0.0            1003.6       100.0         8.5             0.0
# 3       0.050   0.0            1004.0       100.0         8.4             0.0
# 4       0.009   0.0            1004.1       100.0         8.6             0.0
# ...       ...   ...               ...         ...         ...             ...
# 10219   0.006   0.0            1012.8        96.5         9.9            16.0
# 10220   0.009   0.0            1014.0       100.0         5.5            38.0
# 10221   0.187   0.0            1014.6       100.0         3.7            38.0
# 10222   0.009   0.0            1014.8       100.0         9.9            38.0
# 10223   0.007   0.0            1015.4       100.0         9.2            38.0
#
#              date
# 0      2021-09-01
# 1      2021-09-01
# 2      2021-09-01
# 3      2021-09-01
# 4      2021-09-01
# ...           ...
# 10219  2022-10-31
# 10220  2022-10-31
# 10221  2022-10-31
# 10222  2022-10-31
# 10223  2022-10-31
#
# [10224 rows x 16 columns]

# %%
weekly_df = GetWeeklyOutput(test_stdf0_copy,y_pred)
monthly_df = GetMonthlyOutput(test_stdf0_copy,y_pred)
# Out:
# <ipython-input-82-f91ff2dfa88b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['prediction'] = predictionData
# <ipython-input-82-f91ff2dfa88b>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'])
# <ipython-input-83-9e44a5bac22e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['prediction'] = predictionData
# <ipython-input-83-9e44a5bac22e>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'])

# %%
weekly_df
# Out:
#                  output   prediction
# date
# 2021-09-05  2281.933333  1913.367128
# 2021-09-12  2511.142857  2125.245806
# 2021-09-19  1958.333333  1435.699703
# 2021-09-26  1808.285714  1571.389235
# 2021-10-03  2146.000000  1869.563772
# ...                 ...          ...
# 2022-10-09  2661.952381  2848.059799
# 2022-10-16  2089.857143  2581.260526
# 2022-10-23  2156.000000  2418.229648
# 2022-10-30  1622.523810  2060.884242
# 2022-11-06   541.666667   909.472606
#
# [62 rows x 2 columns]

# %%
r2= r2_score(weekly_df['output'], weekly_df['prediction'])
print('R^2:', round(r2, 2))
# Out:
# R^2: 0.89

# %%
monthly_df
# Out:
#                  output   prediction
# date
# 2021-09-30  2173.644444  1801.729698
# 2021-10-31  1672.215054  1476.931573
# 2021-11-30  1615.567268  1645.811092
# 2021-12-31  1046.430108  1033.391004
# 2022-01-31   885.150538  1065.475619
# 2022-02-28  1634.321429  1650.717133
# 2022-03-31  1928.204576  1941.276328
# 2022-04-30  2136.888889  2131.487424
# 2022-05-31  2415.172043  2494.387220
# 2022-06-30  2922.388889  3066.451705
# 2022-07-31  2318.225806  2540.210707
# 2022-08-31  2440.989247  2546.689617
# 2022-09-30  2302.688889  2522.580143
# 2022-10-31  2089.913978  2459.723969

# %%
r2= r2_score(monthly_df['output'], monthly_df['prediction'])
print('R^2:', round(r2, 2))
# Out:
# R^2: 0.88
